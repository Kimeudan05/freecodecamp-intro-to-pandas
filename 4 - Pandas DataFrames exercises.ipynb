# %% [markdown]
# <a href="https://colab.research.google.com/github/Kimeudan05/freecodecamp-intro-to-pandas/blob/master/4%20-%20Pandas%20DataFrames%20exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas DataFrame exercises

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.2
# 2.0.2

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame creation

# %% [markdown]
# ### Create an empty pandas DataFrame

# %%
# your code goes here
pd.DataFrame()
pd.DataFrame(columns=[None], index=[None],data =[None])
# Out:
#       None
# None  None

# %%
pd.DataFrame(data=[None],
             index=[None],
             columns=[None])
# Out:
#       None
# None  None

# %% [markdown]
# <img width=400 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a `marvel_df` pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
# your code goes here
marvel_df  = pd.DataFrame(marvel_data)

marvel_df
#
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
marvel_df = pd.DataFrame(data=marvel_data)

marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add column names to the `marvel_df`

# %%
# your code goes here
marvel_df.columns = ['Name','gender','first_appearance']
marvel_df
# Out:
#                 Name  gender  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# 19            Vision    male              1968

# %%
col_names = ['name', 'sex', 'first_appearance']

marvel_df.columns = col_names
marvel_df
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# 19            Vision    male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add index names to the `marvel_df` (use the character name as index)

# %%
# your code goes here
marvel_df.index = marvel_df['Name']
marvel_df
# Out:
#                               Name  gender  first_appearance
# Name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# Hank Pym                  Hank Pym    male              1962
# Scarlet Witch        Scarlet Witch  female              1964
# Wasp                          Wasp  female              1963
# Black Widow            Black Widow  female              1964
# Vision                      Vision    male              1968

# %%
marvel_df.index = marvel_df['name']
marvel_df

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop the name column as it's now the index

# %%
# your code goes here
marvel_df=marvel_df.drop(columns = 'Name')

# %%
#marvel_df = marvel_df.drop(columns=['name'])
marvel_df = marvel_df.drop(['name'], axis=1)
marvel_df

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop 'Namor' and 'Hank Pym' rows

# %%
# your code goes here
# marvel_df.drop(index =['Hank Pym','Namor'])

marvel_df = marvel_df.drop(['Hank Pym','Namor'],axis=0)
marvel_df
# Out:
#                   gender  first_appearance
# Name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis=0)
marvel_df

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame selection, slicing and indexation

# %% [markdown]
# ### Show the first 5 elements on `marvel_df`

# %%
# your code goes here
# marvel_df.head()
marvel_df.iloc[0:5]
# Out:
#                 gender  first_appearance
# Name
# Spider-Man        male              1962
# Captain America   male              1941
# Wolverine         male              1974
# Iron Man          male              1963
# Thor              male              1963

# %%
#marvel_df.loc[['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor'], :] # bad!
#marvel_df.loc['Spider-Man': 'Thor', :]
#marvel_df.iloc[0:5, :]
#marvel_df.iloc[0:5,]
marvel_df.iloc[:5,]
#marvel_df.head()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the last 5 elements on `marvel_df`

# %%
# your code goes here
# marvel_df.iloc[-5:]
marvel_df.tail()
# Out:
#                 gender  first_appearance
# Name
# Doctor Strange    male              1963
# Scarlet Witch   female              1964
# Wasp            female              1963
# Black Widow     female              1964
# Vision            male              1968

# %%
#marvel_df.loc[['Hank Pym', 'Scarlet Witch', 'Wasp', 'Black Widow', 'Vision'], :] # bad!
#marvel_df.loc['Hank Pym':'Vision', :]
marvel_df.iloc[-5:,]
#marvel_df.tail()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show just the sex of the first 5 elements on `marvel_df`

# %%
# your code goes here
# marvel_df['gender'].head()
# marvel_df.head().gender.to_frame()
marvel_df.iloc[:5,].gender.to_frame()
# Out:
#                 gender
# Name
# Spider-Man        male
# Captain America   male
# Wolverine         male
# Iron Man          male
# Thor              male

# %%
#marvel_df.iloc[:5,]['gender'].to_frame()
marvel_df.iloc[:5,].gender.to_frame()
#marvel_df.head().gender.to_frame()
# Out:
#                 gender
# Name
# Spider-Man        male
# Captain America   male
# Wolverine         male
# Iron Man          male
# Thor              male

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first_appearance of all middle elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[1:-1].first_appearance.to_frame()
# Out:
#                   first_appearance
# Name
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %%
marvel_df.iloc[1:-1,].first_appearance.to_frame()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first and last elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[[0,-1]]
# Out:
#            gender  first_appearance
# Name
# Spider-Man   male              1962
# Vision       male              1968

# %%
#marvel_df.iloc[[0, -1],][['sex', 'first_appearance']]
marvel_df.iloc[[0, -1],]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame manipulation and operations

# %% [markdown]
# ### Modify the `first_appearance` of 'Vision' to year 1964

# %%
# your code goes here
marvel_df.loc['Vision','first_appearance']=1964
marvel_df
# Out:
#                   gender  first_appearance
# Name
# Spider-Man          male            1962.0
# Captain America     male            1941.0
# Wolverine           male            1974.0
# Iron Man            male            1963.0
# Thor                male            1963.0
# Thing               male            1961.0
# Mister Fantastic    male            1961.0
# Hulk                male            1962.0
# Beast               male            1963.0
# Invisible Woman   female            1961.0
# Storm             female            1975.0
# Hawkeye             male            1964.0
# Daredevil           male            1964.0
# Doctor Strange      male            1963.0
# Scarlet Witch     female            1964.0
# Wasp              female            1963.0
# Black Widow       female            1964.0
# Vision              male            1964.0
# Vison                NaN            1964.0

# %%
marvel_df.loc['Vision', 'first_appearance'] = 1964

marvel_df
# Out:
#                   gender  first_appearance
# Name
# Spider-Man          male            1962.0
# Captain America     male            1941.0
# Wolverine           male            1974.0
# Iron Man            male            1963.0
# Thor                male            1963.0
# Thing               male            1961.0
# Mister Fantastic    male            1961.0
# Hulk                male            1962.0
# Beast               male            1963.0
# Invisible Woman   female            1961.0
# Storm             female            1975.0
# Hawkeye             male            1964.0
# Daredevil           male            1964.0
# Doctor Strange      male            1963.0
# Scarlet Witch     female            1964.0
# Wasp              female            1963.0
# Black Widow       female            1964.0
# Vision              male            1964.0
# Vison                NaN            1964.0

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add a new column to `marvel_df` called 'years_since' with the years since `first_appearance`

# %%
# your code goes here
marvel_df['years_since'] = 2025  -marvel_df['first_appearance']
marvel_df
# Out:
#                   gender  first_appearance  years_since
# Name
# Spider-Man          male            1962.0         63.0
# Captain America     male            1941.0         84.0
# Wolverine           male            1974.0         51.0
# Iron Man            male            1963.0         62.0
# Thor                male            1963.0         62.0
# Thing               male            1961.0         64.0
# Mister Fantastic    male            1961.0         64.0
# Hulk                male            1962.0         63.0
# Beast               male            1963.0         62.0
# Invisible Woman   female            1961.0         64.0
# Storm             female            1975.0         50.0
# Hawkeye             male            1964.0         61.0
# Daredevil           male            1964.0         61.0
# Doctor Strange      male            1963.0         62.0
# Scarlet Witch     female            1964.0         61.0
# Wasp              female            1963.0         62.0
# Black Widow       female            1964.0         61.0
# Vision              male            1964.0         61.0
# Vison                NaN            1964.0         61.0

# %%
marvel_df['years_since'] = 2018 - marvel_df['first_appearance']

marvel_df

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame boolean arrays (also called masks)

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, make a mask showing the female characters

# %%
# your code goes here
mask = marvel_df['gender'] =='female'
mask
# Out:
# Name
# Spider-Man          True
# Captain America     True
# Wolverine           True
# Iron Man            True
# Thor                True
# Thing               True
# Mister Fantastic    True
# Hulk                True
# Beast               True
# Invisible Woman     True
# Storm               True
# Hawkeye             True
# Daredevil           True
# Doctor Strange      True
# Scarlet Witch       True
# Wasp                True
# Black Widow         True
# Vision              True
# Vison               True
# Name: gender, dtype: bool

# %%
mask = marvel_df['sex'] == 'female'

mask

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the male characters

# %%
# your code goes here
mask = marvel_df['gender'] == 'male'
# marvel_df[mask]
marvel_df
# Out:
#                   gender  first_appearance  years_since
# Name
# Spider-Man        female            1962.0         63.0
# Captain America   female            1941.0         84.0
# Wolverine         female            1974.0         51.0
# Iron Man          female            1963.0         62.0
# Thor              female            1963.0         62.0
# Thing             female            1961.0         64.0
# Mister Fantastic  female            1961.0         64.0
# Hulk              female            1962.0         63.0
# Beast             female            1963.0         62.0
# Invisible Woman   female            1961.0         64.0
# Storm             female            1975.0         50.0
# Hawkeye           female            1964.0         61.0
# Daredevil         female            1964.0         61.0
# Doctor Strange    female            1963.0         62.0
# Scarlet Witch     female            1964.0         61.0
# Wasp              female            1963.0         62.0
# Black Widow       female            1964.0         61.0
# Vision            female            1964.0         61.0
# Vison             female            1964.0         61.0

# %%
mask = marvel_df['sex'] == 'male'

marvel_df[mask]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with `first_appearance` after 1970

# %%
# your code goes here
mask = marvel_df['first_appearance'] >1970
marvel_df[mask]
# Out:
#            gender  first_appearance  years_since
# Name
# Wolverine  female            1974.0         51.0
# Storm      female            1975.0         50.0

# %%
mask = marvel_df['first_appearance'] > 1970

marvel_df[mask]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the female characters with `first_appearance` after 1970

# %%
# your code goes here
mask = (marvel_df['first_appearance'] > 1970) &( marvel_df['gender'] == 'female')
marvel_df[mask]
# Out:
#            gender  first_appearance  years_since
# Name
# Wolverine  female            1974.0         51.0
# Storm      female            1975.0         50.0

# %%
mask = (marvel_df['sex'] == 'female') & (marvel_df['first_appearance'] > 1970)

marvel_df[mask]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame summary statistics

# %% [markdown]
# ### Show basic statistics of `marvel_df`

# %%
# your code goes here
marvel_df.describe()
# Out:
#        first_appearance  years_since
# count         19.000000    19.000000
# mean        1962.947368    62.052632
# std            6.536000     6.536000
# min         1941.000000    50.000000
# 25%         1962.000000    61.000000
# 50%         1963.000000    62.000000
# 75%         1964.000000    63.000000
# max         1975.000000    84.000000

# %%
marvel_df.describe()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the mean value of `first_appearance`

# %%
# your code goes here
marvel_df['first_appearance'].mean()
# Out:
# np.float64(1962.9473684210527)

# %%
#np.mean(marvel_df.first_appearance)
marvel_df.first_appearance.mean()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
# your code goes here
marvel_df.first_appearance.min()
# Out:
# 1941.0

# %%
#np.min(marvel_df.first_appearance)
marvel_df.first_appearance.min()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with the min value of `first_appearance`

# %%
# your code goes here
# marvel_df[marvel_df['first_appearance'] == marvel_df['first_appearance'].min()]
marvel_df.loc[marvel_df['first_appearance'] == marvel_df['first_appearance'].min()]
# Out:
#                  gender  first_appearance  years_since
# Name
# Captain America  female            1941.0         84.0

# %%
mask = marvel_df['first_appearance'] == marvel_df.first_appearance.min()
marvel_df[mask]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame basic plottings

# %% [markdown]
# ### Reset index names of `marvel_df`

# %%
# your code goes here
marvel_df = marvel_df.reset_index()
marvel_df
# Out:
#                 Name  gender  first_appearance  years_since
# 0         Spider-Man  female            1962.0         63.0
# 1    Captain America  female            1941.0         84.0
# 2          Wolverine  female            1974.0         51.0
# 3           Iron Man  female            1963.0         62.0
# 4               Thor  female            1963.0         62.0
# 5              Thing  female            1961.0         64.0
# 6   Mister Fantastic  female            1961.0         64.0
# 7               Hulk  female            1962.0         63.0
# 8              Beast  female            1963.0         62.0
# 9    Invisible Woman  female            1961.0         64.0
# 10             Storm  female            1975.0         50.0
# 11           Hawkeye  female            1964.0         61.0
# 12         Daredevil  female            1964.0         61.0
# 13    Doctor Strange  female            1963.0         62.0
# 14     Scarlet Witch  female            1964.0         61.0
# 15              Wasp  female            1963.0         62.0
# 16       Black Widow  female            1964.0         61.0
# 17            Vision  female            1964.0         61.0
# 18             Vison  female            1964.0         61.0

# %%
marvel_df = marvel_df.reset_index()

marvel_df

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot the values of `first_appearance`

# %%
# your code goes here
marvel_df['first_appearance'].plot()
# Out:
# <Axes: >

# %%
#plt.plot(marvel_df.index, marvel_df.first_appearance)
marvel_df.first_appearance.plot()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot a histogram (plot.hist) with values of `first_appearance`

# %%
# your code goes here
marvel_df['first_appearance'].plot.hist()
plt.hist(marvel_df.first_appearance)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  3., 13.,  0.,  0.,  2.]),
#  array([1941. , 1944.4, 1947.8, 1951.2, 1954.6, 1958. , 1961.4, 1964.8,
#         1968.2, 1971.6, 1975. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(marvel_df.first_appearance)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
